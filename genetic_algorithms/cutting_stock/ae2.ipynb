# %%
import pandas as pd
import matplotlib.pyplot as plt

from algorithm import CuttingStockGenetic

# %%
# Default plotting settings for matplotlib
plt.rc('figure', figsize=(8, 6), dpi=100)

# %%
r800 = pd.read_csv('data/r800.csv', header=None).rename(columns={0: 'height', 1: 'width', 2: 'value'})
r850 = pd.read_csv('data/r850.csv', header=None).rename(columns={0: 'height', 1: 'width', 2: 'value'})
r1000 = pd.read_csv('data/r1000.csv', header=None).rename(columns={0: 'height', 1: 'width', 2: 'value'})
r1100 = pd.read_csv('data/r1100.csv', header=None).rename(columns={0: 'height', 1: 'width', 2: 'value'})
r1200 = pd.read_csv('data/r1200.csv', header=None).rename(columns={0: 'height', 1: 'width', 2: 'value'})

# %% [markdown]
# # Genetic algorithm

# %% [markdown]
# ## `r800`

# %%
r800
# Out:
#    height  width  value
# 0     250    120    100
# 1     320    160    500
# 2     250    160    600
# 3     150    120     40
# 4     400     30    400

# %%
gen_r800 = CuttingStockGenetic(
    circle_radius=800, rectangles_data=r800,
    population_size=20, random_state=33,
)

# %%
gen_r800.train(
    epochs=400, verbosity_period=50, 
)
# Out:
# Epoch 50 done! Current score: 51300
# Epoch 100 done! Current score: 52400
# Epoch 150 done! Current score: 52800
# Epoch 200 done! Current score: 52400
# Epoch 250 done! Current score: 52920
# Epoch 300 done! Current score: 52920
# Epoch 350 done! Current score: 56000
# Epoch 400 done! Current score: 56000

# %%
gen_r800.best_individual().plot(detailed=False)

# %% [markdown]
# ## `r850`

# %%
r850
# Out:
#    height  width  value
# 0      10    120    120
# 1     120     10    150
# 2     400     20   1200
# 3     300     30   1200
# 4     120    120   1200
# 5     100    100    900
# 6     450     80  11000

# %%
gen_850 = CuttingStockGenetic(
    circle_radius=850, rectangles_data=r850,
    population_size=20, random_state=26,
)

# %%
gen_850.train(
    epochs=100, verbosity_period=25, 
)
# Out:
# Epoch 25 done! Current score: 506260
# Epoch 50 done! Current score: 534480
# Epoch 75 done! Current score: 544190
# Epoch 100 done! Current score: 524800

# %%
gen_850.best_individual().plot(detailed=False)

# %% [markdown]
# ## `r1000`

# %%
r1000
# Out:
#    height  width  value
# 0     200    120    200
# 1     200    160    300
# 2     250    160    500
# 3     100    120     40

# %%
gen_r1000 = CuttingStockGenetic(
    circle_radius=1000, rectangles_data=r1000,
    population_size=20, random_state=24,
)

# %%
gen_r1000.train(
    epochs=100, verbosity_period=25, 
)
# Out:
# Epoch 25 done! Current score: 31980
# Epoch 50 done! Current score: 33040
# Epoch 75 done! Current score: 33200
# Epoch 100 done! Current score: 33200

# %%
gen_r1000.best_individual().plot()

# %% [markdown]
# ## `r1100`

# %%
r1100
# Out:
#    height  width  value
# 0     250    120    100
# 1     120    360    300
# 2     250    160    600
# 3     150    120     40

# %%
gen_1100 = CuttingStockGenetic(
    circle_radius=1100, rectangles_data=r1100,
    population_size=30, random_state=8,
)

# %%
gen_1100.train(
    epochs=100, verbosity_period=25, 
)
# Out:
# Epoch 25 done! Current score: 44460
# Epoch 50 done! Current score: 48100
# Epoch 75 done! Current score: 48600
# Epoch 100 done! Current score: 48600

# %%
gen_1100.best_individual().plot()

# %% [markdown]
# ## `r1200`

# %%
r1200
# Out:
#    height  width  value
# 0     200    120    200
# 1     200    160    300
# 2     250    160    500
# 3     100    120     40

# %%
gen_r1200 = CuttingStockGenetic(
    circle_radius=1200, rectangles_data=r1200,
    population_size=20, random_state=3,
)

# %%
gen_r1200.train(
    epochs=150, verbosity_period=25, 
)
# Out:
# Epoch 25 done! Current score: 47840
# Epoch 50 done! Current score: 48540
# Epoch 75 done! Current score: 48540
# Epoch 100 done! Current score: 48940
# Epoch 125 done! Current score: 48940
# Epoch 150 done! Current score: 48940

# %%
gen_r1200.best_individual().plot()
